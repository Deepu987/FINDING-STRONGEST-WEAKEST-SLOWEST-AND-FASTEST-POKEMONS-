# %%
#importing all important packages
import numpy as np #linear algebra
import pandas as pd #data processing
import matplotlib.pyplot as plt #data visualisation
import seaborn as sns #data visualisation
# %matplotlib inline

# %%
#Input Data
data = pd.read_csv("C:/Users/acer/Downloads/caed/Pokemon.csv") #reading csv file and save it into a variable
data.head(10) #show the first 10 rows in data
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# 5       80       65     80           1      False
# 6      109       85    100           1      False
# 7      130       85    100           1      False
# 8      159      115    100           1      False
# 9       50       64     43           1      False

# %%
data.Name = data.Name.str.replace(".*(?=Mega)", "")
data.head(10)
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_5252\2816696055.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   data.Name = data.Name.str.replace(".*(?=Mega)", "")
#    #              Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0  1         Bulbasaur  Grass  Poison    318  45      49       49       65
# 1  2           Ivysaur  Grass  Poison    405  60      62       63       80
# 2  3          Venusaur  Grass  Poison    525  80      82       83      100
# 3  3     Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4  4        Charmander   Fire     NaN    309  39      52       43       60
# 5  5        Charmeleon   Fire     NaN    405  58      64       58       80
# 6  6         Charizard   Fire  Flying    534  78      84       78      109
# 7  6  Mega Charizard X   Fire  Dragon    634  78     130      111      130
# 8  6  Mega Charizard Y   Fire  Flying    634  78     104       78      159
# 9  7          Squirtle  Water     NaN    314  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False
# 5       65     80           1      False
# 6       85    100           1      False
# 7       85    100           1      False
# 8      115    100           1      False
# 9       64     43           1      False

# %%
data = data.set_index('Name') #change and set the index to the name attribute
data = data.drop(['#'],axis=1) #drop the columns with axis=1; axis=0 is for rows
data.head()
# Out:
#                       Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur              Grass  Poison    318  45      49       49       65
# Ivysaur                Grass  Poison    405  60      62       63       80
# Venusaur               Grass  Poison    525  80      82       83      100
# VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# Charmander              Fire     NaN    309  39      52       43       60
#
#                        Sp. Def  Speed  Generation  Legendary
# Name
# Bulbasaur                   65     45           1      False
# Ivysaur                     80     60           1      False
# Venusaur                   100     80           1      False
# VenusaurMega Venusaur      120     80           1      False
# Charmander                  50     65           1      False

# %%
data['Type 2'].fillna(data['Type 1'], inplace=True)
data.head(10)
# Out:
#    #              Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0  1         Bulbasaur  Grass  Poison    318  45      49       49       65
# 1  2           Ivysaur  Grass  Poison    405  60      62       63       80
# 2  3          Venusaur  Grass  Poison    525  80      82       83      100
# 3  3     Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4  4        Charmander   Fire    Fire    309  39      52       43       60
# 5  5        Charmeleon   Fire    Fire    405  58      64       58       80
# 6  6         Charizard   Fire  Flying    534  78      84       78      109
# 7  6  Mega Charizard X   Fire  Dragon    634  78     130      111      130
# 8  6  Mega Charizard Y   Fire  Flying    634  78     104       78      159
# 9  7          Squirtle  Water   Water    314  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False
# 5       65     80           1      False
# 6       85    100           1      False
# 7       85    100           1      False
# 8      115    100           1      False
# 9       64     43           1      False

# %%
print("Type 1:",data["Type 1"].unique(), "=", len(data["Type 1"].unique()))
print("Type 2:",data["Type 2"].unique(), "=", len(data["Type 2"].unique()))
# Out:
# Type 1: ['Grass' 'Fire' 'Water' 'Bug' 'Normal' 'Poison' 'Electric' 'Ground'
#  'Fairy' 'Fighting' 'Psychic' 'Rock' 'Ghost' 'Ice' 'Dragon' 'Dark' 'Steel'
#  'Flying'] = 18
# Type 2: ['Poison' 'Fire' 'Flying' 'Dragon' 'Water' 'Bug' 'Normal' 'Electric'
#  'Ground' 'Fairy' 'Grass' 'Fighting' 'Psychic' 'Steel' 'Ice' 'Rock' 'Dark'
#  'Ghost'] = 18

# %%
print(data["Type 1"].value_counts())
print(data["Type 2"].value_counts())
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64
# Flying      99
# Water       73
# Psychic     71
# Normal      65
# Grass       58
# Poison      49
# Ground      48
# Fighting    46
# Fire        40
# Fairy       38
# Electric    33
# Dark        30
# Dragon      29
# Steel       27
# Ice         27
# Ghost       24
# Rock        23
# Bug         20
# Name: Type 2, dtype: int64

# %%
strongest = data.sort_values(by='Total', ascending=False) #sorting the rows in descending order
strongest.drop_duplicates(subset=['Type 1'],keep='first')
# Out:
#        #                   Name    Type 1   Type 2  Total   HP  Attack  \
# 426  384          Mega Rayquaza    Dragon   Flying    780  105     180
# 164  150          Mega Mewtwo Y   Psychic  Psychic    780  106     150
# 422  382    KyogrePrimal Kyogre     Water    Water    770  100     150
# 424  383  GroudonPrimal Groudon    Ground     Fire    770  100     180
# 552  493                 Arceus    Normal   Normal    720  120     120
# 413  376         Mega Metagross     Steel  Psychic    700   80     145
# 268  248         Mega Tyranitar      Rock     Dark    700  100     164
# 545  487   GiratinaOrigin Forme     Ghost   Dragon    680  150     120
# 270  250                  Ho-oh      Fire   Flying    680  106     130
# 792  716                Xerneas     Fairy    Fairy    680  126     131
# 793  717                Yveltal      Dark   Flying    680  126     131
# 275  254          Mega Sceptile     Grass   Dragon    630   70     110
# 498  448           Mega Lucario  Fighting    Steel    625   70     145
# 196  181          Mega Ampharos  Electric   Dragon    610   90      95
# 229  212            Mega Scizor       Bug    Steel    600   70     150
# 397  362            Mega Glalie       Ice      Ice    580   80     120
# 703  641  TornadusTherian Forme    Flying   Flying    580   79     100
# 183  169                 Crobat    Poison   Flying    535   85      90
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 426      100      180      100    115           3       True
# 164       70      194      120    140           1       True
# 422       90      180      160     90           3       True
# 424      160      150       90     90           3       True
# 552      120      120      120    120           4       True
# 413      150      105      110    110           3      False
# 268      150       95      120     71           2      False
# 545      100      120      100     90           4       True
# 270       90      110      154     90           2       True
# 792       95      131       98     99           6       True
# 793       95      131       98     99           6       True
# 275       75      145       85    145           3      False
# 498       88      140       70    112           4      False
# 196      105      165      110     45           2      False
# 229      140       65      100     75           2      False
# 397       80      120       80    100           3      False
# 703       80      110       90    121           5       True
# 183       80       70       80    130           2      False

# %%
weakest = data.sort_values(by='Total') #sorting the rows in ascending order
weakest.drop_duplicates(subset=['Type 1'],keep='first')
# Out:
#        #        Name    Type 1    Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 206  191     Sunkern     Grass     Grass    180  30      30       30       30
# 322  298     Azurill    Normal     Fairy    190  50      20       40       20
# 446  401   Kricketot       Bug       Bug    194  37      25       41       25
# 303  280       Ralts   Psychic     Fairy    198  28      25       25       45
# 139  129    Magikarp     Water     Water    200  20      10       55       15
# 186  172       Pichu  Electric  Electric    205  20      40       15       35
# 255  236     Tyrogue  Fighting  Fighting    210  35      35       35       35
# 187  173      Cleffa     Fairy     Fairy    218  50      25       28       45
# 284  261   Poochyena      Dark      Dark    220  35      55       35       30
# 46    41       Zubat    Poison    Flying    245  40      45       35       30
# 790  714      Noibat    Flying    Dragon    245  40      30       35       45
# 238  220      Swinub       Ice    Ground    250  50      50       40       30
# 236  218      Slugma      Fire      Fire    250  40      40       40       70
# 55    50     Diglett    Ground    Ground    265  10      55       25       35
# 668  607     Litwick     Ghost      Fire    275  50      30       55       65
# 583  524  Roggenrola      Rock      Rock    280  55      75       85       25
# 410  374      Beldum     Steel   Psychic    300  40      55       80       35
# 406  371       Bagon    Dragon    Dragon    300  45      75       60       40
#
#      Sp. Def  Speed  Generation  Legendary
# 206       30     30           2      False
# 322       40     20           3      False
# 446       41     25           4      False
# 303       35     40           3      False
# 139       20     80           1      False
# 186       35     60           2      False
# 255       35     35           2      False
# 187       55     15           2      False
# 284       30     35           3      False
# 46        40     55           1      False
# 790       40     55           6      False
# 238       30     50           2      False
# 236       40     20           2      False
# 55        45     95           1      False
# 668       55     20           5      False
# 583       25     15           5      False
# 410       60     30           3      False
# 406       30     50           3      False

# %%
fastest = data.sort_values(by='Speed', ascending=False) #sorting the rows in descending order
fastest.drop_duplicates(subset=['Type 1'],keep='first')
# Out:
#        #               Name    Type 1    Type 2  Total   HP  Attack  Defense  \
# 431  386  DeoxysSpeed Forme   Psychic   Psychic    600   50      95       90
# 315  291            Ninjask       Bug    Flying    456   61      90       45
# 154  142    Mega Aerodactyl      Rock    Flying    615   80     135       85
# 275  254      Mega Sceptile     Grass    Dragon    630   70     110       75
# 109  101          Electrode  Electric  Electric    480   60      50       70
# 476  428       Mega Lopunny    Normal  Fighting    580   65     136       94
# 183  169             Crobat    Poison    Flying    535   85      90       80
# 102   94        Mega Gengar     Ghost    Poison    600   60      65       80
# 731  663         Talonflame      Fire    Flying    499   78      81       71
# 549  491            Darkrai      Dark      Dark    600   70      90       90
# 791  715            Noivern    Flying    Dragon    535   85      70       80
# 726  658           Greninja     Water      Dark    530   72      95       67
# 409  373     Mega Salamence    Dragon    Flying    700   95     145      130
# 56    51            Dugtrio    Ground    Ground    405   35      80       50
# 771  701           Hawlucha  Fighting    Flying    500   78      92       75
# 530  478           Froslass       Ice     Ghost    480   70      80       70
# 413  376     Mega Metagross     Steel   Psychic    700   80     145      150
# 792  716            Xerneas     Fairy     Fairy    680  126     131       95
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 431       95       90    180           3       True
# 315       50       50    160           3      False
# 154       70       95    150           1      False
# 275      145       85    145           3      False
# 109       80       80    140           1      False
# 476       54       96    135           4      False
# 183       70       80    130           2      False
# 102      170       95    130           1      False
# 731       74       69    126           6      False
# 549      135       90    125           4       True
# 791       97       80    123           6      False
# 726      103       71    122           6      False
# 409      120       90    120           3      False
# 56        50       70    120           1      False
# 771       74       63    118           6      False
# 530       80       70    110           4      False
# 413      105      110    110           3      False
# 792      131       98     99           6       True

# %%
slowest = data.sort_values(by='Speed') #sorting the rows in ascending order
slowest.drop_duplicates(subset=['Type 1'],keep='first')
# Out:
#        #          Name    Type 1    Type 2  Total   HP  Attack  Defense  \
# 495  446      Munchlax    Normal    Normal    390  135      85       40
# 230  213       Shuckle       Bug      Rock    505   20      10      230
# 658  597     Ferroseed     Grass     Steel    305   44      50       91
# 486  438        Bonsly      Rock      Rock    290   50      80       95
# 359  328      Trapinch    Ground    Ground    290   45     100       45
# 209  194        Wooper     Water    Ground    210   55      45       45
# 187  173        Cleffa     Fairy     Fairy    218   50      25       28
# 668  607       Litwick     Ghost      Fire    275   50      30       55
# 355  324       Torkoal      Fire      Fire    470   70      85      140
# 327  302  Mega Sableye      Dark     Ghost    480   50      85      125
# 638  577       Solosis   Psychic   Psychic    290   45      30       40
# 484  436       Bronzor     Steel   Psychic    300   57      24       86
# 320  296      Makuhita  Fighting  Fighting    237   72      60       30
# 398  363        Spheal       Ice     Water    290   70      40       50
# 95    88        Grimer    Poison    Poison    325   80      80       50
# 193  179        Mareep  Electric  Electric    280   55      40       40
# 774  704         Goomy    Dragon    Dragon    300   45      50       35
# 790  714        Noibat    Flying    Dragon    245   40      30       35
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 495       40       85      5           4      False
# 230       10      230      5           2      False
# 658       24       86     10           5      False
# 486       10       45     10           4      False
# 359       45       45     10           3      False
# 209       25       25     15           2      False
# 187       45       55     15           2      False
# 668       65       55     20           5      False
# 355       85       70     20           3      False
# 327       85      115     20           3      False
# 638      105       50     20           5      False
# 484       24       86     23           4      False
# 320       20       30     25           3      False
# 398       55       50     25           3      False
# 95        40       50     25           1      False
# 193       65       45     35           2      False
# 774       55       75     40           6      False
# 790       45       40     55           6      False

# %%
sns.set(style = 'darkgrid')
f, ax = plt.subplots(2,1, figsize = (18,10)) #making 2 count plots 

sns.countplot(x = 'Type 1', data = data, order = data['Type 1'].value_counts().index ,ax = ax[0])
sns.countplot(x = 'Type 2', data = data, order = data['Type 2'].value_counts().index ,ax = ax[1])

plt.show()

# %%
Dark       = 30
Steel      = 27
Flying     = 99

f, axs = plt.subplots(2,2, figsize=(20,20))

labels ='Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric', 'Ground', \
        'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost' ,'Ice' ,'Dragon' ,'Dark' , \
        'Steel','Flying'
    
size0 = [95,64,126,72,102,62,50,67,40,53,90,58,46,38,50,51,49,101] #overall count
size1 = [70,52,112,69,98,28,44,32,17,27,57,44,32,24,32,31,27,4] #Type 1 count
size2 = [58,40,73,20,65,49,33,48,38,46,71,23,24,27,29,30,27,99] #Type 2 count

#Overall pie
axs[0,0].pie(size0, labels = labels, autopct='%1.1f%%' ,startangle = 90)
axs[0,0].axis("equal")
axs[0,0].set_title("Overall", size = 20)

#Type1 pie
axs[0,1].pie(size1, labels = labels, autopct='%1.1f%%' ,startangle = 180)
axs[0,1].axis("equal")
axs[0,1].set_title("Type 1", size = 20)

#Type2 pie
axs[1,0].pie(size2, labels = labels, autopct='%1.1f%%' ,startangle = 90)
axs[1,0].axis("equal")
axs[1,0].set_title("Type 2", size = 20)

f.delaxes(axs[1,1]) #deleting axs[1,1] so it will be white blank
plt.show()
